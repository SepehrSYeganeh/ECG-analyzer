# %% [markdown]
# # Save Raw Data

# %%
from prepare_raw_data import save_raw_data

# %%
save_raw_data()

# %% [markdown]
# # Train-Test Split

# %%
from prepare_raw_data import train_test_split

# %%
X100_path = "../data/12lead-ecg-100.npy"
X500_path = "../data/12lead-ecg-500.npy"
Y_path = "../data/metadata.parquet"

# %%
train_test_split(X100_path, Y_path, 100)

# %%
train_test_split(X500_path, Y_path, 500)
