# %%
from pathlib import Path
from ecg_analyzer import ecg_baseline_analysis
from ecg_analyzer.utils import plot_ecg

# %%
test_path = Path.cwd()

# %% [markdown]
# # Test 100

# %%
result = ecg_baseline_analysis(test_path, "00001_lr", "100")

# %%
result.model_dump()
# Out:
# {'filtered_record': {'leads': {'I': [-0.020388390609416187,
#     -0.017138161529147305,
#     -0.020887396416666856,
#     -0.01763618821760721,
#     -0.0033846323401738494,
#     0.0028671732914172243,
#     -0.01888087181430383,
#     0.004371129235486895,
#     0.05262307067285088,
#     0.06387484402803682,
#     0.06912633809304211,
#     0.09937743889037536,
#     0.08462802964757202,
#     -0.013122009222038732,
#     -0.05387280013188306,
#     -0.050624468327639206,
#     -0.040377141885352776,
#     -0.006130951701852823,
#     -0.049886031477130374,
#     -0.07464251768830718,
#     -0.04840054955478769,
#     0.14683973100584963,
#     0.5730781794316984,
#     0.4753146485805938,
#     0.1025489888048203,
#     0.02678104803668022,
#     -0.02698932811513495,
#     -0.026762296258704785,
#     -0.03453801510210269,
#     -0.032316645327292934,
#     -0.07309834945533117,
#     -0.07388329170347924,
#     -0.012671637834811886,
#     -0.05146355500085119,
# ...

# %%
plot_ecg(
    ecg_record=result.filtered_record,
    annotation=result.to_Annotation(),
    title="Analyzed Record"
)

# %% [markdown]
# # Test 500

# %%
result = ecg_baseline_analysis(test_path, "04048_hr", "500")

# %%
result.model_dump()
# Out:
# {'filtered_record': {'leads': {'I': [0.2245838005844048,
#     0.22312799510084078,
#     0.22132242300799848,
#     0.21924537286565288,
#     0.21775991750802257,
#     0.21877879533045172,
#     0.22538601931911,
#     0.2417682356211161,
#     0.2729128649391458,
#     0.32404728763511925,
#     0.3998331279527435,
#     0.5033934611012751,
#     0.6353237867368557,
#     0.7928890259811321,
#     0.9696094804472886,
#     1.1553854764727007,
#     1.3372267697623124,
#     1.5005631880431278,
#     1.6310217489090277,
#     1.716451658017269,
#     1.748864384755598,
#     1.725875791414134,
#     1.6512655106596634,
#     1.5344443407812773,
#     1.3888943298659493,
#     1.229912180564564,
#     1.0721540318089717,
#     0.927506126967615,
#     0.8036940434320535,
#     0.7038370005518754,
#     0.6269195607225578,
#     0.5689497584156775,
#     0.5244451370799905,
#     0.48786696036005234,
#     0.45470508922676367,
#     0.4220591343384362,
#     0.3887128309829356,
# ...

# %%
plot_ecg(
    ecg_record=result.filtered_record,
    annotation=result.to_Annotation(),
    title="Analyzed Record"
)
