# %%
from pathlib import Path
from matplotlib import pyplot as plt
from ecg_analyzer.io import load_ecg_file
from ecg_analyzer.preprocess import qrs_detection_preprocess

# %%
test_path = Path.cwd()

# %% [markdown]
# # Test 100

# %%
rec = load_ecg_file(test_path, "00001_lr", "100")

# %%
signal = qrs_detection_preprocess(rec)

# %%
plt.plot(signal)

# %% [markdown]
# # Test 500

# %%
rec = load_ecg_file(test_path, "04048_hr", "500")

# %%
signal = qrs_detection_preprocess(rec)

# %%
plt.plot(signal)
